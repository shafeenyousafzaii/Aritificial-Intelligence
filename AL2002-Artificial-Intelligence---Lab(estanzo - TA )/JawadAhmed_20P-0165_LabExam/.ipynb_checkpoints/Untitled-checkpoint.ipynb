# %%
## H.H
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


dataset = pd.read_csv('AI_heart.csv')

# %%
dataset.head()
# Out:
#     age sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0  52.0   M   0       125   212    0        1      168      0      1.0      2
# 1  53.0   M   0       140   203    1        0      155      1      3.1      0
# 2  70.0   M   0       145   174    0        1      125      1      2.6      0
# 3  61.0   M   0       148   203    0        1      161      0      0.0      2
# 4  62.0   F   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
label_encoder = LabelEncoder()

dataset['sex'] = label_encoder.fit_transform(dataset['sex'])

# %%
dataset.fillna(dataset.mean(), inplace=True)

# %%
corr_matrix = dataset.corr()
fig, ax = plt.subplots(figsize=(20, 20))
cmap = sns.color_palette("plasma")
sns.heatmap(corr_matrix, cmap=cmap, center=0, square=True, annot=False, ax=ax)
ax.tick_params(axis='both', labelsize=14)
ax.set_title('Correlation Matrix', fontsize=18)
plt.show()

# %%
dataset.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.522210     0.695610     0.942439   131.611707   246.00000
# std       8.651696     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      49.000000     0.000000     0.000000   120.000000   211.00000
# 50%      54.522210     1.000000     1.000000   130.000000   240.00000
# 75%      60.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
columns_to_scale = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
scalar = StandardScaler()

# %%
dataset[columns_to_scale] = scalar.fit_transform(dataset[columns_to_scale])

# %%
corr_matrix = dataset.corr()
corr_target = corr_matrix['target']
top_5_cols = corr_target.abs().sort_values(ascending=False)[1:6]
if 'target' in top_5_cols:
    top_5_cols = top_5_cols.drop(target_var)
top_5_cols_using_corr = top_5_cols.index.tolist()
top_5_cols_using_corr
# Out:
# ['oldpeak', 'exang', 'cp', 'thalach', 'ca']

# %%
corr_features = dataset[top_5_cols_using_corr]

# %%
X = corr_features
y = dataset['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = MLPClassifier(hidden_layer_sizes=(10, 5), activation='relu', solver='adam', max_iter=1000, random_state=1)


model.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 5), max_iter=1000, random_state=1)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8214285714285714

# %%
model2 = MLPClassifier(hidden_layer_sizes=(100, 50), activation='tanh', solver='adam', max_iter=1000, random_state=1)


model.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 5), max_iter=1000, random_state=1)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8214285714285714
