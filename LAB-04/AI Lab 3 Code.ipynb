# %% [markdown]
# # Breath First Search

# %%
import networkx as nx
from collections import deque

def bfs(graph, start, goal):
    visited = set()
    queue = deque([(start, [start])])

    while queue:
        node, path = queue.popleft()
        if node == goal:
            return path
        visited.add(node)

        for neighbor in graph.neighbors(node):
            if neighbor not in visited:
                queue.append((neighbor, path + [neighbor]))

G = nx.Graph()
G.add_edges_from([(0, 1), (0, 2), (1, 2), (2, 0), (2, 3), (3, 3),(3,4),(4,5)])

nx.draw(G, with_labels=True, node_color='lightblue', node_size=1000)

start_node = 0
goal_node = 3
path = bfs(G, start_node, goal_node)

if path:
    print(f"BFS path from node {start_node} to node {goal_node}: {path}")
else:
    print(f"No path found from node {start_node} to node {goal_node}.")
# Out:
# BFS path from node 0 to node 3: [0, 2, 3]

# %% [markdown]
# ## Depth First Search

# %%
import networkx as nx

def dfs(graph, start, goal):
    visited = set()

    def dfs_recursive(node, path):
        if node == goal:
            return path
        visited.add(node)

        for neighbor in graph.neighbors(node):
            if neighbor not in visited:
                new_path = dfs_recursive(neighbor, path + [neighbor])
                if new_path:
                    return new_path
        return None

    return dfs_recursive(start, [start])

G = nx.Graph()
G.add_edges_from([(0, 1), (0, 2), (1, 2), (2, 0), (2, 3), (3, 3)])

nx.draw(G, with_labels=True, node_color='lightblue', node_size=1000)

start_node = 0
goal_node = 3
path = dfs(G, start_node, goal_node)

if path:
    print(f"DFS path from node {start_node} to node {goal_node}: {path}")
else:
    print(f"No path found from node {start_node} to node {goal_node}.")
# Out:
# DFS path from node 0 to node 3: [0, 1, 2, 3]
