# %%
import networkx as nx

# Create a weighted graph
G = nx.Graph()
G.add_weighted_edges_from([('A', 'B', 2), ('A', 'C', 3), ('B', 'D', 5), ('B', 'E', 5), ('C', 'F', 6),('D', 'E', 6)])

# Calculate node positions using spring layout
pos = nx.spring_layout(G)
print(pos)

# Draw the graph with edge labels
nx.draw(G, pos, with_labels=True)
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
# Out:
# {'A': array([0.19392272, 0.11162757]), 'B': array([-0.41810142, -0.2415789 ]), 'C': array([0.68227011, 0.39400996]), 'D': array([-0.65797572, -0.54416384]), 'E': array([-0.80011569, -0.29789749]), 'F': array([1.        , 0.57800271])}
# {('A', 'B'): Text(-0.11208935033506985, -0.06497566789250808, '2'),
#  ('A', 'C'): Text(0.4380964173911802, 0.2528187626769286, '3'),
#  ('B', 'D'): Text(-0.5380385732169091, -0.3928713692288589, '5'),
#  ('B', 'E'): Text(-0.6091085564638461, -0.2697381975668096, '5'),
#  ('C', 'F'): Text(0.8411350554366752, 0.48600633186502107, '6'),
#  ('D', 'E'): Text(-0.7290457051016056, -0.4210306639725123, '6')}
